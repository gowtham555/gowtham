# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham555/gowtham/blob/main/ipl_match_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('IPL2020_Match_data.csv')
print(df)
# Out:
#     Match_id  Match_date  Match_day                        Match_stadium  \
# 0        1.0  19-09-2020   Saturday                 SHEIKH ZAYED STADIUM
# 1        2.0  20-09-2020     Sunday  DUBAI INTERNATIONAL CRICKET STADIUM
# 2        3.0  21-09-2020     Monday  DUBAI INTERNATIONAL CRICKET STADIUM
# 3        4.0  22-09-2020    Tuesday             SHARJAH CRICKET STADIUM,
# 4        5.0  23-09-2020  Wednesday                 SHEIKH ZAYED STADIUM
# 5        6.0  24-09-2020   Thursday  DUBAI INTERNATIONAL CRICKET STADIUM
# 6        7.0  25-09-2020     Friday  DUBAI INTERNATIONAL CRICKET STADIUM
# 7        NaN         NaN        NaN                                  NaN
# 8        NaN         NaN        NaN                                  NaN
# 9        NaN         NaN        NaN                                  NaN
# 10       NaN         NaN        NaN                                  NaN
# 11       NaN         NaN        NaN                                  NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('IPL2020_Match_data.csv')
print(df)
df.isnull().sum()
# Out:
#     Match_id  Match_date  Match_day                        Match_stadium  \
# 0        1.0  19-09-2020   Saturday                 SHEIKH ZAYED STADIUM
# 1        2.0  20-09-2020     Sunday  DUBAI INTERNATIONAL CRICKET STADIUM
# 2        3.0  21-09-2020     Monday  DUBAI INTERNATIONAL CRICKET STADIUM
# 3        4.0  22-09-2020    Tuesday             SHARJAH CRICKET STADIUM,
# 4        5.0  23-09-2020  Wednesday                 SHEIKH ZAYED STADIUM
# 5        6.0  24-09-2020   Thursday  DUBAI INTERNATIONAL CRICKET STADIUM
# 6        7.0  25-09-2020     Friday  DUBAI INTERNATIONAL CRICKET STADIUM
# 7        NaN         NaN        NaN                                  NaN
# 8        NaN         NaN        NaN                                  NaN
# 9        NaN         NaN        NaN                                  NaN
# 10       NaN         NaN        NaN                                  NaN
# 11       NaN         NaN        NaN                                  NaN
# ...

# %%
import numpy as np
df = pd.read_csv('IPL2020_Match_data.csv')
a = np.random.randint(0,10,(3,3))
b = np.random.randint(10,20,(3,3))
print(a)
print(b)
print(np.add(a,b))
print(a.shape)
print(b.shape)
# Out:
# [[9 9 2]
#  [0 9 6]
#  [5 1 9]]
# [[11 16 10]
#  [13 10 16]
#  [16 16 14]]
# [[20 25 12]
#  [13 19 22]
#  [21 17 23]]
# (3, 3)
# (3, 3)

# %%
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv('IPL2020_Match_data.csv')
df.head()
# Out:
#    Match_id  Match_date  Match_day                        Match_stadium  \
# 0       1.0  19-09-2020   Saturday                 SHEIKH ZAYED STADIUM
# 1       2.0  20-09-2020     Sunday  DUBAI INTERNATIONAL CRICKET STADIUM
# 2       3.0  21-09-2020     Monday  DUBAI INTERNATIONAL CRICKET STADIUM
# 3       4.0  22-09-2020    Tuesday             SHARJAH CRICKET STADIUM,
# 4       5.0  23-09-2020  Wednesday                 SHEIKH ZAYED STADIUM
#
#   Location_id Match_location  Season                        Team1  \
# 0         Abu      ABU DHABI  2020.0               Mumbai Indians
# 1          Du          DUBAI  2020.0               Delhi Capitals
# 2          Du          DUBAI  2020.0  Royal Challengers Bangalore
# 3         sha        SHARJAH  2020.0             Rajasthan Royals
# 4         Abu      ABU DHABI  2020.0               Mumbai Indians
#
#                    Team2               Toss_won  ... Team1_sixes Team2_sixes  \
# ...

# %%
plt.figure(figsize=(56,20))
fig,ax = plt.subplots(figsize=(8,9))
sns.displot(df.Umpires)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # New section
